# %%
import bw2data as bd
from collections import defaultdict
from tqdm import tqdm
from thefuzz import fuzz
import bw_processing as bwp
import numpy as np
import math
import stats_arrays as sa

# %%
bd.projects.set_current('GSA for archetypes')

# %%
bd.databases
# Out:
# Databases dictionary with 3 object(s):
# 	biosphere3
# 	ecoinvent 3.8 cutoff
# 	swiss consumption 1.0

# %% [markdown]
# ## Finding liquid fuel combustors

# %%
ei = bd.Database("ecoinvent 3.8 cutoff")

# %% [markdown]
# There are other combustion processes where fuels are measured in megajoules, these will be addressed later.

# %%
flows = ('market for diesel,', 'diesel,', 'petrol,', 'market for petrol,')
liquid_fuels = [x 
                for x in ei 
                if x['unit'] == 'kilogram'
                and((any(x['name'].startswith(flow) for flow in flows) or x['name'] == 'market for diesel'))
               ]
{x['name'] for x in liquid_fuels}
# Out:
# {'diesel, import from RoW',
#  'diesel, low-sulfur, import from Europe',
#  'diesel, low-sulfur, import from RoW',
#  'market for diesel',
#  'market for diesel, low-sulfur',
#  'market for petrol, 15% ETBE additive by volume, with ethanol from biomass',
#  'market for petrol, 4% ETBE additive by volume, with ethanol from biomass',
#  'market for petrol, 5% ethanol by volume from biomass',
#  'market for petrol, low-sulfur',
#  'market for petrol, two-stroke blend',
#  'market for petrol, unleaded',
#  'petrol, low-sulfur, import from Europe',
#  'petrol, unleaded, import from RoW'}

# %% [markdown]
# ### Look into modelling specifics

# %%
# a = liquid_fuels[0]
a = [act for act in ei if 'market for petrol, low-sulfur' in act['name'] and 'Europe without Switzerland'==act['location']][0]
for production in a.production():
    pass

print(production['properties']['carbon content'])
# Out:
# {'amount': 0.865, 'unit': 'dimensionless', 'comment': 'carbon content on a dry matter basis (reserved; not for manual entry)'}

# %%
production
# Out:
# Exchange: 1.0 kilogram 'market for petrol, low-sulfur' (kilogram, Europe without Switzerland, None) to 'market for petrol, low-sulfur' (kilogram, Europe without Switzerland, None)>

# %%
consumer = list(a.consumers())[0]
consumer
# Out:
# Exchange: 0.0641344042785761 kilogram 'market for petrol, low-sulfur' (kilogram, Europe without Switzerland, None) to 'transport, passenger car, medium size, petrol, EURO 4' (kilometer, RER, None)>

# %%
co2 = [x for x in bd.Database('biosphere3') if x['name'] == 'Carbon dioxide, fossil']
co2
# Out:
# ['Carbon dioxide, fossil' (kilogram, None, ('air', 'low population density, long-term')),
#  'Carbon dioxide, fossil' (kilogram, None, ('air',)),
#  'Carbon dioxide, fossil' (kilogram, None, ('air', 'urban air close to ground')),
#  'Carbon dioxide, fossil' (kilogram, None, ('air', 'lower stratosphere + upper troposphere')),
#  'Carbon dioxide, fossil' (kilogram, None, ('air', 'non-urban air or from high stacks'))]

# %%
for exc in consumer.output.biosphere():
    if exc.input in co2:
        print(exc.input)
        break
# Out:
# 'Carbon dioxide, fossil' (kilogram, None, ('air', 'urban air close to ground'))

# %%
exc
# Out:
# Exchange: 0.207834603648 kilogram 'Carbon dioxide, fossil' (kilogram, None, ('air', 'urban air close to ground')) to 'transport, passenger car, medium size, petrol, EURO 4' (kilometer, RER, None)>

# %%
total_co2 = sum(exc['amount'] for exc in consumer.output.biosphere() if exc.input in co2)
total_co2
# Out:
# 0.207834603648

# %%
production['properties']
# Out:
# {'water in wet mass': {'amount': 0.0, 'unit': 'kg'},
#  'carbon content, fossil': {'amount': 0.865,
#   'unit': 'dimensionless',
#   'comment': 'C-content is 86.5% (ecoinvent v2.2 report 6_IV, Tab 3.13)'},
#  'water content': {'amount': 0.0,
#   'unit': 'dimensionless',
#   'comment': 'water mass/dry mass'},
#  'dry mass': {'amount': 1.0, 'unit': 'kg'},
#  'price': {'amount': 0.71,
#   'unit': 'EUR2005',
#   'comment': 'Average calculated from All Grades, Areas and Formulations in USA for 2005. Source: http://www.eia.gov/oil_gas/petroleum/data_publications/wrgp/mogas_history.html'},
#  'heating value, net': {'amount': 42.5,
#   'unit': 'MJ',
#   'comment': 'Based on literature, page 611, Report 17: Jungbluth, N., Chudacoff, M., Dauriat, A., Dinkel, F., Doka, G., Faist Emmenegger, M., Gnansounou, E., Kljun, N., Schleiss, K., Spielmann, M., Stettler, C., Sutter, J. 2007: Life Cycle Inventories of Bioenergy. ecoinvent report No. 17, Swiss Centre for Life Cycle Inventories, Dübendorf, CH.'},
#  'wet mass': {'amount': 1.0, 'unit': 'kg'},
#  'carbon content, non-fossil': {'amount': 0.0, 'unit': 'dimensionless'},
#  'carbon content': {'amount': 0.865,
#   'unit': 'dimensionless',
#   'comment': 'carbon content on a dry matter basis (reserved; not for manual entry)'},
#  'carbon allocation': {'amount': 0.865,
#   'unit': 'kg',
#   'comment': 'carbon content per unit of product (reserved; not for manual entry)'}}

# %%
set([act['name'] for act in ei if "land" in act['name']])
# Out:
# {'anchovy, capture by steel purse seiner and landing whole, fresh',
#  'anchovy, capture by wooden purse seiner and landing whole, fresh',
#  'cement production, Portland',
#  'clear-cutting, grassland to arable land, annual crop',
#  'clear-cutting, grassland to arable land, forest, intensive',
#  'clear-cutting, grassland to arable land, pasture, man made',
#  'clear-cutting, grassland to arable land, perennial crop',
#  'clear-cutting, primary forest to arable land, annual crop',
#  'clear-cutting, primary forest to arable land, forest, intensive',
#  'clear-cutting, primary forest to arable land, pasture, man made',
#  'clear-cutting, primary forest to arable land, perennial crop',
#  'clear-cutting, secondary forest to arable land, annual crop',
#  'clear-cutting, secondary forest to arable land, perennial crop',
#  'concrete production, 20MPa, ready-mix, with Portland cement',
#  'concrete production, 20MPa, self-construction, with Portland cement',
#  'concrete production, 40MPa, ready-mix, with Portland cement',
#  'grass production, permanent grassland, Swiss integrated production, extensive',
#  'grass production, permanent grassland, Swiss integrated production, intensive',
#  'grass production, permanent grassland, organic, extensive',
#  'grass production, permanent grassland, organic, intensive',
#  'hake, capture by long liner and landing whole, fresh',
#  'hake, capture by trawler and landing whole, fresh',
#  'inert material landfill construction',
#  'land already in use, annual cropland to annual crop',
#  'land already in use, annual cropland to forest, intensive',
#  'land already in use, annual cropland to pasture, man made',
#  'land already in use, annual cropland to perennial crop',
#  'land already in use, forest, intensive to annual crop',
#  'land already in use, forest, intensive to pasture, man made',
#  'land already in use, forest, intensive to perennial crop',
#  'land already in use, pasture, man made to annual crop',
#  'land already in use, pasture, man made to forest, intensive',
#  'land already in use, pasture, man made to perennial crop',
#  'land already in use, perennial cropland to annual crop',
#  'land already in use, perennial cropland to forest, intensive',
#  'land already in use, perennial cropland to pasture, man made',
#  'land already in use, perennial cropland to perennial crop',
#  'land use change, annual crop',
#  'land use change, forest, intensive',
#  'land use change, paddy rice',
#  'land use change, pasture, man made',
#  'land use change, perennial crop',
#  'landed anchovy by-catch, fresh to generic market for marine fish',
#  'landed anchovy to generic market for marine fish',
#  'landed hake to generic market for marine fish',
#  'landed tuna to generic market for marine fish',
#  'market for cement, Portland',
#  'market for cement, portland fly ash cement 21-35%',
#  'market for cement, portland fly ash cement 6-20%',
#  'market for inert material landfill',
#  'market for land tenure, arable land, measured as carbon net primary productivity, annual crop',
#  'market for land tenure, arable land, measured as carbon net primary productivity, forest, intensive',
#  'market for land tenure, arable land, measured as carbon net primary productivity, pasture, man made',
#  'market for land tenure, arable land, measured as carbon net primary productivity, perennial crop',
#  'market for land use change, annual crop',
#  'market for land use change, forest, intensive',
#  'market for land use change, paddy rice',
#  'market for land use change, pasture, man made',
#  'market for land use change, perennial crop',
#  'market for landed anchovy by-catch, fresh',
#  'market for landed anchovy, fresh',
#  'market for landed hake, fresh',
#  'market for landed tuna, frozen, EPO',
#  'market for process-specific burdens, import of copper to Switzerland',
#  'market for process-specific burdens, inert material landfill',
#  'market for process-specific burdens, residual material landfill',
#  'market for process-specific burdens, sanitary landfill',
#  'market for process-specific burdens, slag landfill',
#  'market for residual material landfill',
#  'market for sanitary landfill facility',
#  'market for slag landfill',
#  'market for transport, freight, inland waterways, barge',
#  'market for transport, freight, inland waterways, barge tanker',
#  'market for transport, freight, inland waterways, barge with reefer, cooling',
#  'market for transport, freight, inland waterways, barge with reefer, freezing',
#  'market group for land use change, annual crop',
#  'market group for land use change, forest, intensive',
#  'market group for land use change, pasture, man made',
#  'market group for land use change, perennial crop',
#  'market group for transport, freight, inland waterways, barge',
#  'market group for transport, freight, inland waterways, barge tanker',
#  'patagonian grenadier, capture by trawler and landing in fish blocks, frozen',
#  'process-specific burdens, import of copper to Switzerland',
#  'process-specific burdens, inert material landfill',
#  'process-specific burdens, residual material landfill',
#  'process-specific burdens, sanitary landfill',
#  'process-specific burdens, slag landfill',
#  'pulpwood, softwood, measured as solid wood under bark, import from Europe without Switzerland',
#  'residual material landfill construction',
#  'sanitary landfill facility construction',
#  'sawlog and veneer log, hardwood, measured as solid wood under bark, import from Europe without Switzerland',
#  'sawlog and veneer log, softwood, measured as solid wood under bark, import from Europe without Switzerland',
#  'slag landfill construction',
#  'transport, freight, inland waterways, barge',
#  'transport, freight, inland waterways, barge tanker',
#  'transport, freight, inland waterways, barge with reefer, cooling',
#  'transport, freight, inland waterways, barge with reefer, freezing',
#  'treatment of H3PO4 purification residue, residual material landfill',
#  'treatment of ash from deinking sludge, residual material landfill',
#  'treatment of ash from paper production sludge, residual material landfill',
#  'treatment of average incineration residue, residual material landfill',
#  'treatment of basic oxygen furnace dust, residual material landfill',
#  'treatment of basic oxygen furnace secondary metallurgy slag, residual material landfill',
#  'treatment of basic oxygen furnace slag, residual material landfill',
#  'treatment of basic oxygen furnace sludge, residual material landfill',
#  'treatment of basic oxygen furnace waste, residual material landfill',
#  'treatment of blast furnace dust, residual material landfill',
#  'treatment of blast furnace sludge, residual material landfill',
#  'treatment of copper slag, residual material landfill',
#  'treatment of decarbonising waste, residual material landfill',
#  'treatment of decommissioned pipeline, natural gas, inert material landfill',
#  'treatment of drilling waste, landfarming',
#  'treatment of drilling waste, residual material landfill',
#  'treatment of dross from Al electrolysis, residual material landfill',
#  'treatment of electric arc furnace dust, residual material landfill',
#  'treatment of electric arc furnace secondary metallurgy slag, residual material landfill',
#  'treatment of electric arc furnace slag, residual material landfill',
#  'treatment of filter dust from Al electrolysis, residual material landfill',
#  'treatment of glass cullet, from fluorescent lamps treatment, 0% water, inert material landfill',
#  'treatment of glass cullet, from used cathode ray tube panels, 0% water, inert material landfill',
#  'treatment of glass cullet, lead containing, from used cathode ray tube, 0% water, inert material landfill',
#  'treatment of glass cullet, mixed glass from used cathode ray tube, 0% water, inert material landfill',
#  'treatment of green liquor dregs, residual material landfill',
#  'treatment of hard coal ash, residual material landfill',
#  'treatment of hard coal ash, sanitary landfill',
#  'treatment of inert waste, inert material landfill',
#  'treatment of inert waste, sanitary landfill',
#  'treatment of lead smelter slag, residual material landfill',
#  'treatment of lignite ash, sanitary landfill',
#  'treatment of limestone residue, inert material landfill',
#  'treatment of mill scale, residual material landfill',
#  'treatment of municipal solid waste, sanitary landfill',
#  'treatment of municipal solid waste, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of municipal solid waste, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of municipal solid waste, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of municipal solid waste, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of municipal solid waste, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of nickel smelter slag, residual material landfill',
#  'treatment of pollutant from rail ballast, residual material landfill',
#  'treatment of redmud from bauxite digestion, residual material landfill',
#  'treatment of refinery sludge, landfarming',
#  'treatment of refinery sludge, sanitary landfill',
#  'treatment of refractory spent pot liner from Al electrolysis, residual material landfill',
#  'treatment of residue from Na-dichromate production, residual material landfill',
#  'treatment of residue from TiO2 production, chloride process, residual material landfill',
#  'treatment of residue from TiO2 production, sulfate process, residual material landfill',
#  'treatment of residue from cooling tower, sanitary landfill',
#  'treatment of residue from rutile production, synthetic, 56% water, residual material landfill',
#  'treatment of salt tailing from potash mine, residual material landfill',
#  'treatment of scrap steel, inert material landfill',
#  'treatment of scrap tin sheet, sanitary landfill',
#  'treatment of slag from metallurgical grade silicon production, inert material landfill',
#  'treatment of sludge from pulp and paper production, sanitary landfill',
#  'treatment of sludge from steel rolling, residual material landfill',
#  'treatment of sludge, NaCl electrolysis Hg, residual material landfill',
#  'treatment of sludge, NaCl electrolysis, residual material landfill',
#  'treatment of spent Formox catalyst base from formaldehyde production, residual material landfill',
#  'treatment of spent catalyst base from ethyleneoxide production, residual material landfill',
#  'treatment of spent pot liner from Al electrolysis, carbon fraction, residual material landfill',
#  'treatment of spoil from hard coal mining, in surface landfill',
#  'treatment of spoil from lignite mining, in surface landfill',
#  'treatment of tin slag, residual material landfill',
#  'treatment of waste aluminium, sanitary landfill',
#  'treatment of waste asphalt, sanitary landfill',
#  'treatment of waste bitumen, sanitary landfill',
#  'treatment of waste cement, hydrated, residual material landfill',
#  'treatment of waste concrete, inert material landfill',
#  'treatment of waste emulsion paint, inert material landfill',
#  'treatment of waste emulsion paint, sanitary landfill',
#  'treatment of waste frit from cathode ray tube production, residual material landfill',
#  'treatment of waste glass, inert material landfill',
#  'treatment of waste glass, sanitary landfill',
#  'treatment of waste glass, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste glass, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste glass, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste glass, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste glass, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste graphical paper, sanitary landfill',
#  'treatment of waste graphical paper, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste graphical paper, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste graphical paper, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste graphical paper, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste graphical paper, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste gypsum, inert material landfill',
#  'treatment of waste gypsum, sanitary landfill',
#  'treatment of waste mineral wool, inert material landfill',
#  'treatment of waste packaging paper, sanitary landfill',
#  'treatment of waste paint, inert material landfill',
#  'treatment of waste paint, sanitary landfill',
#  'treatment of waste paperboard, inert material landfill',
#  'treatment of waste paperboard, sanitary landfill',
#  'treatment of waste paperboard, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste paperboard, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste paperboard, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste paperboard, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste paperboard, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste plastic plaster, inert material landfill',
#  'treatment of waste plastic plaster, sanitary landfill',
#  'treatment of waste plastic, consumer electronics, sanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste plastic, consumer electronics, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste plastic, mixture, sanitary landfill',
#  'treatment of waste plastic, mixture, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste plastic, mixture, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste plastic, mixture, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste plastic, mixture, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste plastic, mixture, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste polyethylene terephthalate, sanitary landfill',
#  'treatment of waste polyethylene terephthalate, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste polyethylene terephthalate, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste polyethylene terephthalate, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste polyethylene terephthalate, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste polyethylene terephthalate, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste polyethylene, sanitary landfill',
#  'treatment of waste polyethylene, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste polyethylene, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste polyethylene, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste polyethylene, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste polyethylene, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste polypropylene, sanitary landfill',
#  'treatment of waste polypropylene, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste polypropylene, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste polypropylene, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste polypropylene, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste polypropylene, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste polystyrene, sanitary landfill',
#  'treatment of waste polystyrene, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste polystyrene, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste polystyrene, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste polystyrene, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste polystyrene, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste polyurethane, inert material landfill',
#  'treatment of waste polyurethane, sanitary landfill',
#  'treatment of waste polyurethane, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste polyurethane, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste polyurethane, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste polyurethane, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste polyurethane, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste polyvinylchloride, sanitary landfill',
#  'treatment of waste polyvinylchloride, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste polyvinylchloride, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste polyvinylchloride, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste polyvinylchloride, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste polyvinylchloride, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste wood, untreated, sanitary landfill',
#  'treatment of waste wood, untreated, unsanitary landfill, dry infiltration class (100mm)',
#  'treatment of waste wood, untreated, unsanitary landfill, hyperarid infiltration class (-250mm)',
#  'treatment of waste wood, untreated, unsanitary landfill, moist infiltration class (300mm)',
#  'treatment of waste wood, untreated, unsanitary landfill, very wet infiltration class (1000mm)',
#  'treatment of waste wood, untreated, unsanitary landfill, wet infiltration class (500mm)',
#  'treatment of waste yarn and waste textile, unsanitary landfill',
#  'treatment of waste zeolite, inert material landfill',
#  'treatment of waste, from silicon wafer production, inorganic, residual material landfill',
#  'treatment of wood ash mixture, pure, landfarming',
#  'treatment of wood ash mixture, pure, sanitary landfill',
#  'treatment of zinc slag, residual material landfill',
#  'treatment, sludge from pulp and paper production, landfarming',
#  'tuna, capture by purse seiner and landing whole, frozen'}

# %%
[act for act in ei if "plant" in act['name']]
# Out:
# ['heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, IE, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, DE, None),
#  'market for anaerobic digestion plant, agricultural' (unit, GLO, None),
#  'market for planting, sugarcane' (hectare, GLO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IT, None),
#  'tomato seedling production, in unheated greenhouse, for planting' (unit, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-CQ, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-SA, None),
#  'electricity production, solar tower power plant, 20 MW' (kilowatt hour, US-WECC, None),
#  'gas motor production, mini CHP plant' (unit, RoW, None),
#  'process-specific burdens, hazardous waste incineration plant' (kilogram, RoW, None),
#  'market for gas motor, mini CHP plant' (unit, GLO, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CA-PE, None),
#  'weaned calves production on native and planted pasture, Pantanal' (kilogram, BR, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CA-BC, None),
#  'nuclear power plant construction, pressure water reactor, 1000MW' (unit, RoW, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, SK, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IE, None),
#  'market for generator, mini CHP plant' (unit, GLO, None),
#  'nuclear power plant construction, pressure water reactor, 1000MW' (unit, FR, None),
#  'market for wind power plant, 800kW, fixed parts' (unit, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, RoW, None),
#  'application of plant protection product, by field sprayer' (hectare, RoW, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CA-NB, None),
#  'sugarcane processing, traditional annexed plant' (kilogram, BR, None),
#  'compressed air energy storage plant construction, 200 MW electrical' (unit, RER, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, CA-NT, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-HB, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-GX, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, US-NPCC, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, HU, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-HA, None),
#  'electricity production, solar tower power plant, 20 MW' (kilowatt hour, RoW, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-GJ, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, FI, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-UP, None),
#  'market for power block, solar tower power plant, 20 MW' (unit, GLO, None),
#  'market for potato planting' (hectare, GLO, None),
#  'fish freezing plant construction and maintenance' (unit, PE, None),
#  'nuclear power plant construction, boiling water reactor 1000MW' (unit, RoW, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CA-AB, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, TR, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, AT, None),
#  'heat pump production, for mini CHP plant' (unit, RoW, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, TR, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-TN, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, FI, None),
#  'vanilla seedling production, for planting' (unit, RoW, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-SC, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, MX, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, AU, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, AU, None),
#  'heating and sanitary equipment production, mini CHP plant' (unit, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, CA-NS, None),
#  'anaerobic digestion plant construction, agriculture, with methane recovery' (unit, RoW, None),
#  'market for geothermal power plant, 5.5MWel' (unit, GLO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-HL, None),
#  'application of plant protection product, by field sprayer' (hectare, CA-QC, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, CA-MB, None),
#  'anaerobic digestion plant construction, agricultural' (unit, CH, None),
#  'treatment of waste glass pane in burnable frame, sorting plant' (kilogram, CH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-TR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, RO, None),
#  'hydropower plant construction, reservoir, alpine region' (unit, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, EE, None),
#  'market for thermal storage system, solar tower power plant, 20 MW' (unit, GLO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, SA, None),
#  'market for process-specific burdens, hazardous waste incineration plant' (kilogram, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-GA, None),
#  'treatment of waste plaster-cardboard sandwich, sorting plant' (kilogram, CH, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-RJ, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-NX, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, NL, None),
#  'market for eucalyptus seedling, for planting' (unit, GLO, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, RS, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, NL, None),
#  'miscanthus rhizome production, for planting' (unit, RoW, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, US-NPCC, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-AB, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, SE, None),
#  'catalytic converter production, three-way, mini CHP plant' (unit, CH, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, SK, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IT, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, CO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-XJ, None),
#  'lignite power plant construction' (unit, RER, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-NB, None),
#  'planting, sugarcane' (hectare, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, US-SERC, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-HN, None),
#  'market for jute plant, harvested' (kilogram, GLO, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-GZ, None),
#  'treatment of coal gas, in power plant' (megajoule, HR, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, NO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, KR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-SK, None),
#  'market for fish freezing plant' (unit, GLO, None),
#  'maintenance, mini CHP plant' (unit, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-HU, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, HR, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, GB, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, US-RFC, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-AP, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, HR, None),
#  'market for onion seedling, for planting' (unit, GLO, None),
#  'gas motor production, mini CHP plant' (unit, CH, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, US-ASCC, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, LU, None),
#  'sugarcane processing, modern autonomous plant' (kilogram, BR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, NO, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, EE, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, BR, None),
#  'generator production, mini CHP plant' (unit, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, CZ, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, NL, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CO, None),
#  'hydropower plant construction, reservoir' (unit, CA-QC, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, FR, None),
#  'nuclear power plant construction, boiling water reactor 1000MW' (unit, DE, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, BG, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, BE, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-KL, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, NO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-JX, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, CA-PE, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CA-NS, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-SA, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, TR, None),
#  'geothermal power plant construction' (unit, IS, None),
#  'market for mini CHP plant, components for heat only' (unit, GLO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-ZJ, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, MY, None),
#  'treatment of waste paint on metal, sorting plant' (kilogram, CH, None),
#  'hardwood forestry, eucalyptus ssp., planted forest management' (kilogram, BR-GO, None),
#  'market for planting tree' (unit, GLO, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, PL, None),
#  'market for flax plant, harvested' (kilogram, GLO, None),
#  'catalytic converter production, three-way, mini CHP plant' (unit, RoW, None),
#  'mini CHP plant production, components for heat only' (unit, CH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-HA, None),
#  'geothermal power plant construction' (unit, RoW, None),
#  'treatment of waste concrete, not reinforced, sorting plant' (kilogram, RoW, None),
#  'treatment of coal gas, in power plant' (megajoule, DE, None),
#  'treatment of waste mineral plaster, sorting plant' (kilogram, CH, None),
#  'treatment of waste paint on wall, sorting plant' (kilogram, CH, None),
#  'market for application of plant protection product, by field sprayer' (hectare, GLO, None),
#  'nuclear power plant construction, pressure water reactor, 1000MW' (unit, CN, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-NB, None),
#  'ethanol fermentation plant construction' (unit, RoW, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, AT, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-AB, None),
#  'sugarcane processing, traditional annexed plant' (kilogram, BR, None),
#  'treatment of waste mineral wool, sorting plant' (kilogram, Europe without Switzerland, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, ES, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, UA, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, SI, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, DK, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, RS, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, KR, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, US-WECC, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, CA-BC, None),
#  'anaerobic digestion plant construction, agricultural' (unit, RoW, None),
#  'nuclear power plant construction, pressure water reactor, 1000MW' (unit, US, None),
#  'anaerobic digestion plant construction, for biowaste' (unit, CH, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, DE, None),
#  'treatment of coal gas, in power plant' (megajoule, IT, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-SC, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, US-RFC, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, FR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-GX, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, SE, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-XZ, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, MK, None),
#  'market for fishmeal plant' (unit, GLO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-JX, None),
#  'weaned calves production on native and planted pasture, Pantanal' (kilogram, BR, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, IE, None),
#  'market for willow stem cutting, for planting' (unit, GLO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CA-AB, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-HL, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, BA, None),
#  'market for gas power plant, combined cycle, 400MW electrical' (unit, GLO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, AT, None),
#  'sugarcane processing, traditional annexed plant' (kilogram, BR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, RS, None),
#  'mini CHP plant production, components for electricity only' (unit, RoW, None),
#  'sugarcane processing, traditional annexed plant' (kilogram, RoW, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-KL, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, AT, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, FR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, US-TRE, None),
#  'concentrated solar power plant construction, solar thermal parabolic trough, 50 MW' (unit, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CZ, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, TW, None),
#  'treatment of coal gas, in power plant' (megajoule, RoW, None),
#  'treatment of waste polyurethane seal, sorting plant' (kilogram, CH, None),
#  'geothermal power plant construction' (unit, SV, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, GB, None),
#  'strawberry seedling production, in unheated greenhouse, for planting' (unit, ES, None),
#  'treatment of coal gas, in power plant' (megajoule, RS, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, TR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-PE, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-XJ, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, SK, None),
#  'heat and power co-generation, natural gas, mini-plant 2KW electrical' (megajoule, RoW, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, CZ, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-JS, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, HR, None),
#  'drying of maize straw and whole-plant' (litre, CH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-RJ, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, US-ASCC, None),
#  'geothermal power plant construction, Hot-Dry-Rock' (unit, GLO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-HN, None),
#  'market for planning, cogen unit mini CHP plant' (unit, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, NL, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, TR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, US-MRO, None),
#  'mango seedling production, for planting' (unit, RoW, None),
#  'treatment of coal gas, in power plant' (megajoule, NL, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, BR-Northern grid, None),
#  'tomato seedling production, in heated greenhouse, for planting' (unit, RoW, None),
#  'market for fish curing plant' (unit, GLO, None),
#  'treatment of coal gas, in power plant' (megajoule, FI, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, CA-AB, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, US-TRE, None),
#  'heat pump production, for mini CHP plant' (unit, CH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-PY, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, SK, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, TW, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, US-SERC, None),
#  'treatment of coal gas, in power plant' (megajoule, FR, None),
#  'onion seedling production, for planting' (unit, NZ, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, HU, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, NO, None),
#  'willow stem cutting production, for planting' (unit, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None),
#  'market for tomato seedling, for planting' (unit, GLO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, US-TRE, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-AH, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, RU, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, UA, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, HU, None),
#  'wind power plant construction, 800kW, moving parts' (unit, GLO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, CA-AB, None),
#  'sugarcane processing, modern autonomous plant' (kilowatt hour, BR, None),
#  'fish freezing plant construction and maintenance' (unit, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, TR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-GS, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, FI, None),
#  'market for assembly of generator and motor, auxilliaries and energy use, for mini CHP plant' (unit, GLO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, DE, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, ES, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, IT, None),
#  'market for ethanol fermentation plant' (unit, GLO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, RU, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, SA, None),
#  'treatment of waste plastic plaster, sorting plant' (kilogram, CH, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CA-ON, None),
#  'market for heat pump, for mini CHP plant' (unit, GLO, None),
#  'steam generation system construction, solar tower power plant, 20 MW' (unit, RoW, None),
#  'market for mango seedling, for planting' (unit, GLO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, KR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-QC, None),
#  'treatment of coal gas, in power plant' (megajoule, BG, None),
#  'planting, tree' (unit, RoW, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, BG, None),
#  'hydropower plant construction, reservoir' (unit, RoW, None),
#  'market for geothermal power plant, undefined type' (unit, GLO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, ES, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, DE, None),
#  'storage production, 650 l mini CHP plant' (unit, CH, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-NX, None),
#  'treatment of coal gas, in power plant' (megajoule, SK, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, BA, None),
#  'market for photovoltaic plant, 570kWp, multi-Si, on open ground' (unit, GLO, None),
#  'market for steam generation system, solar tower power plant, 20 MW' (unit, GLO, None),
#  'market for compressed air energy storage plant, adiabatic, 150 MW electrical' (unit, GLO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, LU, None),
#  'treatment of coal gas, in power plant' (megajoule, BE, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, SA, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, ES, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, AR, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, DE, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-GZ, None),
#  'treatment of coal gas, in power plant' (megajoule, GB, None),
#  'nuclear power plant construction, boiling water reactor 1000MW' (unit, CH, None),
#  'geothermal power plant construction' (unit, CH, None),
#  'market for maintenance, mini CHP plant' (unit, GLO, None),
#  'treatment of coal gas, in power plant' (megajoule, KR, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, CA-ON, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, BR-North-eastern grid, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, MX, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, LV, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, PT, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, BG, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, FR, None),
#  'planting, sugarcane' (hectare, BR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, PE, None),
#  'market for planting' (hectare, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-GZ, None),
#  'anaerobic digestion plant construction, for sewage sludge' (unit, CH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, FI, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-NM, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-NX, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, US-WECC, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, UA, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, SA, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, DK, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, IR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, NO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, SK, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, AT, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-YN, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, IE, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, FR, None),
#  'hard coal power plant construction, 100MW' (unit, GLO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-GD, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, GB, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-FJ, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, LU, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, LT, None),
#  'fish canning plant construction and maintenance' (unit, RLA, None),
#  'miscanthus rhizome production, for planting' (unit, DE, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, NL, None),
#  'market for tree seedling, for planting' (unit, RER, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, RU, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, GR, None),
#  'market for miscanthus rhizome, for planting' (unit, GLO, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, GR, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-TJ, None),
#  'power block installation, solar tower power plant, 20 MW' (unit, ZA, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, MK, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, JP, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, SI, None),
#  'heat and power co-generation, natural gas, mini-plant 2KW electrical' (kilowatt hour, RoW, None),
#  'treatment of waste bulk iron, excluding reinforcement, sorting plant' (kilogram, CH, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, KR, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-NX, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-ON, None),
#  'market for hard coal power plant' (unit, GLO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, TH, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, UA, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, TW, None),
#  'market for tree seedling, for planting' (unit, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, NL, None),
#  'gas power plant construction, combined cycle, 400MW electrical' (unit, RER, None),
#  'electric parts production, mini CHP plant' (unit, RoW, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, MK, None),
#  'weaned calves production on native and planted pasture, Pantanal' (kilogram, BR, None),
#  'treatment of waste reinforced concrete, sorting plant' (kilogram, CH, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, TW, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, BR-Mid-western grid, None),
#  'geothermal power plant construction' (unit, KE, None),
#  'treatment of waste brick, sorting plant' (kilogram, Europe without Switzerland, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-ZJ, None),
#  'market for drying of maize straw and whole-plant' (litre, GLO, None),
#  'geothermal power plant construction' (unit, CR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, HU, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-MB, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-ON, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, CA-NB, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CA-NT, None),
#  'electricity production, hard coal, at coal mine power plant' (kilowatt hour, RoW, None),
#  'market for electric parts, mini CHP plant' (unit, GLO, None),
#  'hydropower plant construction, run-of-river' (unit, CA-QC, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, LV, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, BR-South-eastern grid, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, PT, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, FI, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, PL, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, BG, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, ZA, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-FJ, None),
#  'concentrated solar power plant construction, solar tower power plant, 20 MW' (unit, ZA, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-MB, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, RO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, MY, None),
#  'treatment of waste reinforced plasterboard, sorting plant' (kilogram, CH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-SH, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, RO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, PE, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-JS, None),
#  'market for lignite power plant' (unit, GLO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, GB, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, BE, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, PL, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-GX, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, ID, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-PY, None),
#  'sugarcane processing, traditional annexed plant' (kilogram, CO, None),
#  'treatment of rainwater mineral oil storage, in wastewater treatment plant, capacity 1.1E10l/year' (cubic meter, Europe without Switzerland, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, IR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-GD, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, GR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, FR, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, RS, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, ES, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, US-RFC, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, AT, None),
#  'treatment of waste reinforced concrete, sorting plant' (kilogram, RoW, None),
#  'hydropower plant construction, reservoir, non-alpine regions' (unit, RoW, None),
#  'market for planting with starter fertiliser, by no till planter' (hectare, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-HR, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, LU, None),
#  'onion seedling production, for planting' (unit, RoW, None),
#  'treatment of waste brick, sorting plant' (kilogram, CH, None),
#  'fishmeal and fish oil plant construction and maintenance' (unit, PE, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, BR-Southern grid, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, RO, None),
#  'treatment of coal gas, in power plant' (megajoule, PL, None),
#  'market for hard coal preparation plant' (unit, GLO, None),
#  'market for concentrated solar power plant, solar thermal parabolic trough, 50 MW' (unit, GLO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, SE, None),
#  'gas power plant construction, 300MW electrical' (unit, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CA-MB, None),
#  'concentrated solar power plant construction, solar tower power plant, 20 MW' (unit, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, KR, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, CA-PE, None),
#  'nuclear power plant construction, pressure water reactor 650MW' (unit, CA-QC, None),
#  'concentrated solar power plant construction, solar thermal parabolic trough, 50 MW' (unit, ZA, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CA-AB, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, CA-NS, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, BA, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-LN, None),
#  'nuclear power plant construction, pressure water reactor 650MW' (unit, RoW, None),
#  'treatment of coal gas, in power plant' (megajoule, AT, None),
#  'market for geothermal power plant, Hot-Dry-Rock' (unit, GLO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, US-SERC, None),
#  'sugarcane processing, modern annexed plant' (kilogram, BR, None),
#  'power block installation, solar tower power plant, 20 MW' (unit, RoW, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-AH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-SX, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, UA, None),
#  'heat and power co-generation, natural gas, mini-plant 2KW electrical' (megajoule, Europe without Switzerland, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, LU, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-ZJ, None),
#  'wind power plant construction, 800kW, fixed parts' (unit, GLO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-HL, None),
#  'asparagus seedling production, for planting' (unit, FR, None),
#  'hydropower plant construction, reservoir, non-alpine regions' (unit, RER, None),
#  'market for concentrated solar power plant, solar tower, 20 MW' (unit, GLO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, HR, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, IT, None),
#  'treatment of waste paint on wall, sorting plant' (kilogram, RoW, None),
#  'treatment of coal gas, in power plant' (megajoule, TW, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-CQ, None),
#  'hard coal preparation plant construction' (unit, GLO, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, LV, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, PE, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CO, None),
#  'treatment of coal gas, in power plant' (megajoule, BR, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, NO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CA-PE, None),
#  'market for gas power plant, 300MW electrical' (unit, GLO, None),
#  'hardwood forestry, eucalyptus ssp., planted forest management' (kilogram, BR-SP, None),
#  'strawberry seedling production, in heated greenhouse, for planting' (unit, NL, None),
#  'nuclear power plant construction, boiling water reactor 1000MW' (unit, US, None),
#  'geothermal power plant construction' (unit, NZ, None),
#  'heat and power co-generation, natural gas, mini-plant 2KW electrical' (kilowatt hour, CH, None),
#  'sugarcane processing, modern annexed plant' (kilogram, BR, None),
#  'treatment of waste mineral wool, sorting plant' (kilogram, RoW, None),
#  'thermal storage system construction, solar tower power plant, 20 MW' (unit, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, PL, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, LT, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-HR, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-XJ, None),
#  'sugarcane processing, traditional annexed plant' (kilogram, RoW, None),
#  'treatment of coal gas, in power plant' (megajoule, TR, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-NM, None),
#  'market for gas power plant, 100MW electrical' (unit, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, BR-South-eastern grid, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, RoW, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-HE, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, TW, None),
#  'miscanthus rhizome production, for planting' (kilogram, DE, None),
#  'treatment of waste concrete gravel, sorting plant' (kilogram, CH, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CZ, None),
#  'hydropower plant construction, reservoir, alpine region' (unit, RER, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-QH, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, BA, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-JL, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, TW, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-HU, None),
#  'treatment of waste emulsion paint on wall, sorting plant' (kilogram, RoW, None),
#  'fish curing plant construction and maintenance' (unit, RoW, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, BG, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-QH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, US-ASCC, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, AR, None),
#  'treatment of waste glass sheet, sorting plant' (kilogram, RoW, None),
#  'collector field area construction, solar tower power plant, 20 MW' (unit, ZA, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-CQ, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-HU, None),
#  'thermal storage system construction, solar tower power plant, 20 MW' (unit, ZA, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, FI, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, US-WECC, None),
#  'thermal storage system construction, solar tower power plant, 20 MW' (kilogram, ZA, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-BJ, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-GA, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, IT, None),
#  'hardwood forestry, eucalyptus ssp., planted forest management' (kilogram, BR-MG, None),
#  'sugarcane processing, traditional annexed plant' (kilogram, CO, None),
#  'planting, potato' (hectare, CH, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, RU, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-HA, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, HU, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-TR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, US-RFC, None),
#  'mini CHP plant construction, common components for heat+electricity' (unit, RoW, None),
#  'treatment of waste emulsion paint on wall, sorting plant' (kilogram, CH, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, HR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, AU, None),
#  'tomato seedling production, in unheated greenhouse, for planting' (unit, ES, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-NT, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-SX, None),
#  'hydropower plant construction, run-of-river' (unit, CH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-LN, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-NS, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, AR, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, HR, None),
#  'hard coal power plant construction, 500MW' (unit, GLO, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-XZ, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, TR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CZ, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, IT, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, MX, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, HR, None),
#  'hydropower plant construction, reservoir' (unit, CH, None),
#  'market for anaerobic digestion plant, for biowaste' (unit, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, NO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-GX, None),
#  'treatment of waste mineral plaster, sorting plant' (kilogram, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, GR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, BG, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, DK, None),
#  'nuclear power plant construction, pressure water reactor, 1000MW' (unit, CH, None),
#  'heating and sanitary equipment production, mini CHP plant' (unit, CH, None),
#  'miscanthus rhizome production, for planting' (kilogram, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, HU, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-QH, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-NS, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-JL, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CZ, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, IE, None),
#  'treatment of waste reinforcement steel, sorting plant' (kilogram, CH, None),
# ...
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, AU, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-JL, None),
#  'collector field area construction, solar tower power plant, 20 MW' (unit, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CY, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CH, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, SK, None),
#  'treatment of waste bulk iron, excluding reinforcement, sorting plant' (kilogram, Europe without Switzerland, None),
#  'treatment of waste concrete gravel, sorting plant' (kilogram, RoW, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, AU, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-SH, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, EE, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-SX, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, AU, None),
#  'geothermal power plant construction' (unit, NI, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, BR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-AH, None),
#  'process-specific burdens, hazardous waste incineration plant' (kilogram, CH, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, AR, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-GD, None),
#  'oil power plant construction, 500MW' (unit, RER, None),
#  'sugarcane processing, traditional autonomous plant' (kilogram, BR, None),
#  'fruit tree seedling production, for planting' (unit, CH, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, US-NPCC, None),
#  'glass wool mat production, with plant-based binder, uncoated, Saint-Gobain ISOVER SA' (kilogram, CH, None),
#  'compressed air energy storage plant construction, adiabatic, 150 MW electrical' (unit, RoW, None),
#  'treatment of coal gas, in power plant' (megajoule, CA-NS, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, US-NPCC, None),
#  'fishmeal and fish oil plant construction and maintenance' (unit, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, SE, None),
#  'treatment of coal gas, in power plant' (megajoule, CA-NB, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, PT, None),
#  'treatment of coal gas, in power plant' (megajoule, UA, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-DL, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, LT, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-TJ, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, PT, None),
#  'market for mini CHP plant, components for electricity only' (unit, GLO, None),
#  'vanilla seedling production, for planting' (unit, MG, None),
#  'market for strawberry seedling, for planting' (unit, GLO, None),
#  'market for receiver system, solar tower power plant, 20 MW' (unit, GLO, None),
#  'treatment of coal gas, in power plant' (megajoule, HU, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, US-TRE, None),
#  'maintenance, mini CHP plant' (unit, CH, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-SD, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-TJ, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-BJ, None),
#  'market for storage, 650 l mini CHP plant' (unit, GLO, None),
#  'market for process-specific burdens, hazardous waste incineration plant' (kilogram, CH, None),
#  'sugarcane processing, traditional annexed plant' (kilogram, BR, None),
#  'hydropower plant construction, run-of-river' (unit, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, LT, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, NL, None),
#  'market for fruit tree seedling, for planting' (unit, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-DL, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IR, None),
#  'electric parts production, mini CHP plant' (unit, CH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-MH, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-GS, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-SK, None),
#  'market for catalytic converter, three-way, mini CHP plant' (unit, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, BR-Mid-western grid, None),
#  'storage production, 650 l mini CHP plant' (unit, RoW, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, US-MRO, None),
#  'market for anaerobic digestion plant, agriculture, with methane recovery' (unit, GLO, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, NL, None),
#  'treatment of coal gas, in power plant' (megajoule, IR, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, RU, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-FJ, None),
#  'treatment of coal gas, in power plant' (megajoule, CA-PE, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, FI, None),
#  'assembly of generator and motor, auxilliaries and energy use, for mini CHP plant' (unit, CH, None),
#  'anaerobic digestion plant construction, for biowaste' (unit, RoW, None),
#  'receiver system construction, solar tower power plant, 20 MW' (unit, ZA, None),
#  'market for mint seedling, for planting' (unit, GLO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, RU, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, US-WECC, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, NL, None),
#  'drying of maize straw and whole-plant' (litre, RoW, None),
#  'electricity production, solar tower power plant, 20 MW' (kilowatt hour, AU, None),
#  'planning, cogen unit mini CHP plant' (unit, RoW, None),
#  'receiver system construction, solar tower power plant, 20 MW' (unit, RoW, None),
#  'planting with starter fertiliser, by no till planter' (hectare, RoW, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, US-ASCC, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, CA-QC, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, DE, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, ID, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, BE, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-YN, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-PE, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, MT, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-TN, None),
#  'treatment of waste glass pane in burnable frame, sorting plant' (kilogram, RoW, None),
#  'mini CHP plant production, components for heat only' (unit, RoW, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, RO, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, BE, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-ZJ, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, HU, None),
#  'market for asparagus seedling, for planting' (unit, GLO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-CQ, None),
#  'market for natural gas processing plant' (unit, GLO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, TZ, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, ES, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, SK, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, HR, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-AH, None),
#  'treatment of coal gas, in power plant' (megajoule, SE, None),
#  'hardwood forestry, eucalyptus ssp., planted forest management' (kilogram, RoW, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, KR, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CA-NB, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, BR, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, JP, None),
#  'treatment of waste reinforcement steel, sorting plant' (kilogram, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, US-ASCC, None),
#  'treatment of waste glass sheet, sorting plant' (kilogram, Europe without Switzerland, None),
#  'treatment of waste cement in concrete and mortar, sorting plant' (kilogram, RoW, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, SE, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, CA-NB, None),
#  'mini CHP plant construction, common components for heat+electricity' (unit, CH, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-YN, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, BE, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, US-TRE, None),
#  'treatment of waste bulk iron, excluding reinforcement, sorting plant' (kilogram, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-AS, None),
#  'treatment of coal gas, in power plant' (megajoule, CA-ON, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-NM, None),
#  'market for wind power plant, 800kW, moving parts' (unit, GLO, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, GR, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-HE, None),
#  'oil power plant construction, 500MW' (unit, RoW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-BJ, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, US-WECC, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, HU, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, US-MRO, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, RoW, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-SA, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-SX, None),
#  'asparagus seedling production, for planting' (unit, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, BG, None),
#  'treatment of rainwater mineral oil storage, in wastewater treatment plant, capacity 1.1E10l/year' (cubic meter, CH, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, BG, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-SD, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-LN, None),
#  'market for anaerobic digestion plant, for sewage sludge' (unit, GLO, None),
#  'sugarcane processing, traditional annexed plant' (kilogram, CO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-NT, None),
#  'steam generation system construction, solar tower power plant, 20 MW' (unit, ZA, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, FI, None),
#  'sugarcane processing, modern annexed plant' (kilogram, BR, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, TH, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, CN-SA, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, AT, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-SD, None),
#  'treatment of coal gas, in power plant' (megajoule, RU, None),
#  'market for nuclear power plant, boiling water reactor 1000MW' (unit, GLO, None),
#  'mini CHP plant production, components for electricity only' (unit, CH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, US-MRO, None),
#  'market for sunn hemp plant, harvested' (kilogram, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-HN, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, RS, None),
#  'heat and power co-generation, natural gas, mini-plant 2KW electrical' (megajoule, CH, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, RO, None),
#  'market for mini CHP plant, common components for heat+electricity' (unit, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, ES, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, IR, None),
#  'treatment of waste reinforced concrete, sorting plant' (kilogram, Europe without Switzerland, None),
#  'compressed air energy storage plant construction, adiabatic, 150 MW electrical' (unit, RER, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, TW, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-NM, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, US-SERC, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-XJ, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, RU, None),
#  'natural gas processing plant production' (unit, GLO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (megajoule, RoW, None),
#  'fish canning plant construction and maintenance' (unit, RoW, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-SC, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, HU, None),
#  'treatment of blast furnace gas, in power plant' (megajoule, IR, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CA-NS, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, US-NPCC, None),
#  'market for kenaf plant, harvested' (kilogram, GLO, None)]

# %%
[act for act in ei if "plant" in act['name']]

# %%
consumer['amount'] / production['amount'] * production['properties']['carbon content']['amount'] * (12 + 16 * 2) / 12

# %% [markdown]
# These numbers don't match because there is a second petrol input. Let's write a validation function.

# %%
consumer.input

# %%
def carbon_fuel_emissions_balanced(activity, fuels, co2):
    """Check that we can rescale carbon in fuel to CO2 emissions by checking their stoichiometry.
    
    Returns a ``bool`."""
    try:
        total_carbon = sum(
            # Carbon content amount is fraction of mass, unitless
            exc['amount'] * exc['properties']['carbon content']['amount'] 
            for exc in activity.technosphere() 
            if exc.input in fuels)
    except KeyError:
        return False
    conversion = 12 / (12 + 16 * 2)
    total_carbon_in_co2 = sum(
        exc['amount'] * conversion
        for exc in activity.biosphere()
        if exc.input in co2
    )
    print(total_carbon, total_carbon_in_co2)
    return math.isclose(total_carbon, total_carbon_in_co2, rel_tol=1e-06, abs_tol=1e-3)

# %%
carbon_fuel_emissions_balanced(consumer.input, liquid_fuels, co2)

# %%
for exc in consumer.input.biosphere():
    if exc.input in co2:
        print(exc.input)

# %%
for exc in consumer.input.technosphere():
    if exc.input in liquid_fuels:
        print(exc.input)

# %% [markdown]
# We also need an iterator that will return scaling factors sampled from the uncertainty. Note that we need to add all the carbon together to get the rescaling correct.

# %%
def get_samples_and_scaling_vector(activity, fuels, size=10, seed=None):
    """Draw ``size`` samples from technosphere exchanges for ``activity`` whose inputs are in ``fuels``.
    
    Returns:
        * Numpy indices array with shape ``(len(found_exchanges)),)``
        * Numpy flip array with shape ``(len(found_exchanges,))``
        * Numpy data array with shape ``(size, len(found_exchanges))``
        * Scaling vector with relative total carbon consumption and shape ``(size,)``.
    """
    exchanges = [exc for exc in activity.technosphere() if exc.input in fuels]
    static_total = sum(exc['amount'] * exc['properties']['carbon content']['amount'] for exc in exchanges)
    sample = sa.MCRandomNumberGenerator(
        sa.UncertaintyBase.from_dicts(*[exc.as_dict() for exc in exchanges]), 
        seed=seed
    ).generate(samples=size)
    indices = np.array([(exc.input.id, exc.output.id) for exc in exchanges], dtype=bwp.INDICES_DTYPE)
    carbon_fraction = np.array([exc['properties']['carbon content']['amount'] for exc in exchanges]).reshape((-1, 1))
    carbon_total_per_sample = (sample * carbon_fraction).sum(axis=0).ravel()
    flip = np.ones(indices.shape, dtype=bool)
    assert carbon_total_per_sample.shape == (size,)
    return indices, flip, sample, carbon_total_per_sample / static_total

# %%
get_samples_and_scaling_vector(consumer.output, liquid_fuels)

# %%
def rescale_biosphere_exchanges_by_factors(activity, factors, flows):
    """Rescale biosphere exchanges with flows ``flows`` from ``activity`` by vector ``factors``.
    
    ``flows`` are biosphere flow objects, with e.g. all the CO2 flows, but also other flows such as metals, volatile organics, etc. 
    Only rescales flows in ``flows`` which are present in ``activity`` exchanges.
    
    Assumes the static values are balanced, i.e. won't calculate CO2 emissions from carbon in 
    fuels but just rescales given values.

    Returns: Numpy indices and data arrays with shape (number of exchanges found, len(factors)).
    Returns:
        * Numpy indices array with shape ``(len(found_exchanges)),)``
        * Numpy flip array with shape ``(len(found_exchanges,))``
        * Numpy data array with shape ``(len(found_exchanges), len(factors))``
    """
    indices, data = [], []
    assert isinstance(factors, np.ndarray) and len(factors.shape) == 1
    
    for exc in activity.biosphere():
        if exc.input in flows:
            indices.append((exc.input.id, exc.output.id))
            data.append(factors * exc['amount'])
            
    return np.array(indices, dtype=bwp.INDICES_DTYPE), np.zeros(len(indices), dtype=bool), np.vstack(data)

# %%
i, d = rescale_biosphere_exchanges_by_factors(consumer.output, np.linspace(0.8, 1.2, 10), co2)
i, d

# %%
d.shape
